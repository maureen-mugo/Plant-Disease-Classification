# %% [markdown]
# # Plant Disease Classification - Training and Inferencing

# %% [markdown]
# This notebook explores training and inferencing of Resnet50 baseline model for Plant Disease Classificaton. Here, we use machine learning techniques to improve the performance of the baseline model.

# %% [markdown]
# ### Importing Libraries needed

# %% [markdown]
# First, we import all  the necessary libraries for data analysis as seen below:

# %%
# importing the fastai libraries for computer vision
from fastcore.all import *
from fastai.vision.all import *

# %%
#imoorting supplementary libraries
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Setting the Data path object

# %% [markdown]
# We then set up the path object from our downloaded dataset directory as seen below:

# %%
data_dir = '/home/roach/Maureen/Plant Disease/data'

# %%
path = Path(data_dir)

# %% [markdown]
# ### Putting Data in Dataloaders

# %% [markdown]
# In this section we load our data into Dataloaders which is a class that allows data to be loaded for training. Additionally, it simplifies processes like batch loading, data augmentation, data resizing, splitting data into training and validation, among others.

# %%
# Define a DataBlock for image classification using fastai
plt_dis = DataBlock(
    # Specify the types of blocks (ImageBlock for images, CategoryBlock for categories/labels)
    blocks=(ImageBlock, CategoryBlock),
    
    # Function to get the items (in this case, image files)
    get_items=get_image_files,
    
    # Splitter function to split data into training and validation sets randomly (with a seed for reproducibility)
    splitter=RandomSplitter(seed=42),
    
    # Function to get the labels (in this case, parent folder labels)
    get_y=parent_label,
    
    # Transformations to apply to each item (resizing images to 460x460)
    item_tfms=Resize(460),
    
    # Batch-level transformations (data augmentations like resizing and random flips)
    batch_tfms=aug_transforms(size=224, min_scale=0.75)
)

# %%
# Create DataLoaders using the plt_dis DataBlock for image classification on the dataset located at 'path'.
dls = plt_dis.dataloaders(path)

# %% [markdown]
# ### Training Resnet50 baseline model

# %%
learn = vision_learner(dls, resnet50, metrics = accuracy)
learn.fine_tune(2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.601110</td>
#       <td>0.338041</td>
#       <td>0.888411</td>
#       <td>06:32</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.257000</td>
#       <td>0.192410</td>
#       <td>0.937852</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136534</td>
#       <td>0.124013</td>
#       <td>0.960928</td>
#       <td>07:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.most_confused(min_val=5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('Soybean__diabrotica_speciosa', 'Soybean__caterpillar', 44),
#  ('Rice__leaf_blast', 'Rice__healthy', 26),
#  ('Corn__northern_leaf_blight', 'Corn__gray_leaf_spot', 25),
#  ('Coffee__red_spider_mite', 'Coffee__rust', 24),
#  ('Rice__brown_spot', 'Rice__leaf_blast', 23),
#  ('Soybean__caterpillar', 'Soybean__diabrotica_speciosa', 23),
#  ('Rice__brown_spot', 'Rice__healthy', 20),
#  ('Cassava__brown_streak_disease', 'Cassava__healthy', 19),
#  ('Soybean__caterpillar', 'Soybean__healthy', 18),
#  ('Cassava__healthy', 'Cassava__bacterial_blight', 16),
#  ('Cassava__brown_streak_disease', 'Cassava__bacterial_blight', 14),
#  ('Soybean__diabrotica_speciosa', 'Soybean__healthy', 14),
#  ('Corn__gray_leaf_spot', 'Corn__northern_leaf_blight', 12),
#  ('Cassava__healthy', 'Cassava__brown_streak_disease', 11),
#  ('Cassava__mosaic_disease', 'Cassava__green_mottle', 10),
#  ('Cassava__bacterial_blight', 'Cassava__brown_streak_disease', 9),
#  ('Cassava__green_mottle', 'Cassava__mosaic_disease', 9),
#  ('Cassava__healthy', 'Cassava__mosaic_disease', 9),
#  ('Rice__leaf_blast', 'Rice__brown_spot', 9),
#  ('Cassava__bacterial_blight', 'Cassava__healthy', 8),
#  ('Cassava__mosaic_disease', 'Cassava__healthy', 8),
#  ('Coffee__rust', 'Coffee__healthy', 8),
#  ('Cassava__green_mottle', 'Cassava__healthy', 7),
#  ('Cassava__healthy', 'Cassava__green_mottle', 7),
#  ('Tomato__bacterial_spot', 'Tomato__target_spot', 7),
#  ('Cassava__brown_streak_disease', 'Cassava__green_mottle', 6),
#  ('Lemon__diseased', 'Lemon__healthy', 6),
#  ('Potato__early_blight', 'Potato__late_blight', 6),
#  ('Potato__late_blight', 'Potato__early_blight', 6),
#  ('Apple__scab', 'Apple__rust', 5),
#  ('Cassava__bacterial_blight', 'Cassava__mosaic_disease', 5),
#  ('Cassava__brown_streak_disease', 'Cassava__mosaic_disease', 5),
#  ('Cassava__green_mottle', 'Cassava__bacterial_blight', 5),
#  ('Cassava__green_mottle', 'Cassava__brown_streak_disease', 5),
#  ('Chili__yellowish', 'Chili__leaf curl', 5)]

# %%
interp.plot_top_losses(3, nrows=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### Improving our model

# %%
import gc
import torch

def clear_memory():
    gc.collect()
    torch.cuda.empty_cache()
    
clear_memory()

# %%
learn = vision_learner(dls, resnet50, metrics=accuracy)
lr_min,lr_steep = learn.lr_find(suggest_funcs=(minimum, steep))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")
# Out:
# Minimum/10: 1.45e-02, steepest point: 4.37e-03

# %%
learn = vision_learner(dls, resnet50, metrics=accuracy)
learn.fit_one_cycle(3, 3e-3)
learn.unfreeze()
learn.fit_one_cycle(14, lr_max=slice(1e-6,1e-4))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.428328</td>
#       <td>0.273155</td>
#       <td>0.910539</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.239583</td>
#       <td>0.159439</td>
#       <td>0.947272</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150196</td>
#       <td>0.134030</td>
#       <td>0.955364</td>
#       <td>06:34</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.161130</td>
#       <td>0.135790</td>
#       <td>0.954985</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.146132</td>
#       <td>0.132202</td>
#       <td>0.956439</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.129093</td>
#       <td>0.123675</td>
#       <td>0.958779</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.122211</td>
#       <td>0.118227</td>
#       <td>0.960422</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.115638</td>
#       <td>0.113287</td>
#       <td>0.963963</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.106739</td>
#       <td>0.111553</td>
#       <td>0.963773</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.100505</td>
#       <td>0.108959</td>
#       <td>0.964785</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.094160</td>
#       <td>0.106065</td>
#       <td>0.965227</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.084941</td>
#       <td>0.105546</td>
#       <td>0.966049</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.090668</td>
#       <td>0.105774</td>
#       <td>0.965480</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.080271</td>
#       <td>0.103338</td>
#       <td>0.966555</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.091698</td>
#       <td>0.103246</td>
#       <td>0.966681</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.082250</td>
#       <td>0.103501</td>
#       <td>0.966745</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.076166</td>
#       <td>0.102653</td>
#       <td>0.967693</td>
#       <td>07:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.most_confused(min_val=5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('Soybean__diabrotica_speciosa', 'Soybean__caterpillar', 33),
#  ('Rice__leaf_blast', 'Rice__healthy', 25),
#  ('Soybean__caterpillar', 'Soybean__diabrotica_speciosa', 22),
#  ('Coffee__red_spider_mite', 'Coffee__rust', 21),
#  ('Cassava__healthy', 'Cassava__bacterial_blight', 18),
#  ('Rice__brown_spot', 'Rice__leaf_blast', 16),
#  ('Cassava__brown_streak_disease', 'Cassava__healthy', 15),
#  ('Cassava__healthy', 'Cassava__brown_streak_disease', 15),
#  ('Rice__brown_spot', 'Rice__healthy', 14),
#  ('Soybean__diabrotica_speciosa', 'Soybean__healthy', 14),
#  ('Cassava__brown_streak_disease', 'Cassava__bacterial_blight', 12),
#  ('Cassava__mosaic_disease', 'Cassava__green_mottle', 11),
#  ('Corn__northern_leaf_blight', 'Corn__gray_leaf_spot', 11),
#  ('Rice__leaf_blast', 'Rice__brown_spot', 11),
#  ('Cassava__healthy', 'Cassava__mosaic_disease', 10),
#  ('Soybean__caterpillar', 'Soybean__healthy', 10),
#  ('Cassava__bacterial_blight', 'Cassava__healthy', 9),
#  ('Cassava__green_mottle', 'Cassava__mosaic_disease', 9),
#  ('Cassava__mosaic_disease', 'Cassava__healthy', 8),
#  ('Potato__early_blight', 'Potato__late_blight', 8),
#  ('Rice__healthy', 'Rice__leaf_blast', 8),
#  ('Cassava__brown_streak_disease', 'Cassava__green_mottle', 7),
#  ('Cassava__green_mottle', 'Cassava__healthy', 7),
#  ('Coffee__rust', 'Coffee__healthy', 7),
#  ('Corn__gray_leaf_spot', 'Corn__northern_leaf_blight', 7),
#  ('Cassava__bacterial_blight', 'Cassava__brown_streak_disease', 6),
#  ('Cassava__brown_streak_disease', 'Cassava__mosaic_disease', 6),
#  ('Lemon__diseased', 'Lemon__healthy', 5),
#  ('Potato__late_blight', 'Potato__early_blight', 5)]

# %%
interp.plot_top_losses(3, nrows=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export()
